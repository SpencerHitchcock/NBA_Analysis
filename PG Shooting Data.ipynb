# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import teams
from nba_api.stats.static import players
import pandas as pd
import numpy as np

# %%
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players[:5]
# Out:
# Number of players fetched: 4393
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False}]

# %%
hornets = [team for team in nba_teams
         if team['full_name'] == 'Charlotte Hornets'][0]
hornets
# Out:
# {'id': 1610612766,
#  'full_name': 'Charlotte Hornets',
#  'abbreviation': 'CHA',
#  'nickname': 'Hornets',
#  'city': 'Charlotte',
#  'state': 'North Carolina',
#  'year_founded': 1988}

# %%
kemba = [player for player in nba_players
                   if player['full_name'] == 'Kemba Walker'][0]
kemba
# Out:
# {'id': 202689,
#  'full_name': 'Kemba Walker',
#  'first_name': 'Kemba',
#  'last_name': 'Walker',
#  'is_active': True}

# %%
kemba_career = playercareerstats.PlayerCareerStats(player_id='202689')
kemba_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202689   2011-12        00  1610612766               CHA        22.0
# 1     202689   2012-13        00  1610612766               CHA        23.0
# 2     202689   2013-14        00  1610612766               CHA        24.0
# 3     202689   2014-15        00  1610612766               CHA        25.0
# 4     202689   2015-16        00  1610612766               CHA        26.0
# 5     202689   2016-17        00  1610612766               CHA        27.0
# 6     202689   2017-18        00  1610612766               CHA        28.0
# 7     202689   2018-19        00  1610612766               CHA        29.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  66  25  1792.0  281  ...    0.789    30   204  234  289   60   20  119
# 1  82  82  2859.0  526  ...    0.798    60   223  283  471  160   31  200
# ...

# %%
kemba_career = kemba_career.get_data_frames()[0]
kemba_career = kemba_career.loc[:, ['PLAYER_ID','PLAYER_AGE', 'FG3M', 'FG3A', 'FG3_PCT']]
kemba_career.head(10)
# Out:
#    PLAYER_ID  PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0     202689        22.0    69   226    0.305
# 1     202689        23.0   107   332    0.322
# 2     202689        24.0   109   327    0.333
# 3     202689        25.0    85   280    0.304
# 4     202689        26.0   182   490    0.371
# 5     202689        27.0   240   602    0.399
# 6     202689        28.0   231   601    0.384
# 7     202689        29.0   260   731    0.356

# %%
kemba_career.to_csv('Kemba_Walker_Career.csv')

# %%
dame = [player for player in nba_players
                   if player['full_name'] == 'Damian Lillard'][0]
dame
# Out:
# {'id': 203081,
#  'full_name': 'Damian Lillard',
#  'first_name': 'Damian',
#  'last_name': 'Lillard',
#  'is_active': True}

# %%
dame_career = playercareerstats.PlayerCareerStats(player_id='203081')
dame_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203081   2012-13        00  1610612757               POR        22.0
# 1     203081   2013-14        00  1610612757               POR        23.0
# 2     203081   2014-15        00  1610612757               POR        24.0
# 3     203081   2015-16        00  1610612757               POR        25.0
# 4     203081   2016-17        00  1610612757               POR        26.0
# 5     203081   2017-18        00  1610612757               POR        27.0
# 6     203081   2018-19        00  1610612757               POR        28.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  82  82  3167.0  553  ...    0.844    42   215  257  531   74   19  243
# 1  82  82  2937.0  553  ...    0.871    35   253  288  457   64   22  193
# 2  82  82  2925.0  590  ...    0.864    49   329  378  507   97   21  222
# ...

# %%
dame_career = dame_career.get_data_frames()[0]
dame_career = dame_career.loc[:, ['PLAYER_AGE', 'FG3M', 'FG3A', 'FG3_PCT']]
dame_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0   185   503    0.368
# 1        23.0   218   554    0.394
# 2        24.0   196   572    0.343
# 3        25.0   229   610    0.375
# 4        26.0   214   579    0.370
# 5        27.0   227   629    0.361
# 6        28.0   237   643    0.369

# %%
dame_career.to_csv('Dame_Lillard_Career.csv')

# %%
steph = [player for player in nba_players
                   if player['full_name'] == 'Stephen Curry'][0]
steph
# Out:
# {'id': 201939,
#  'full_name': 'Stephen Curry',
#  'first_name': 'Stephen',
#  'last_name': 'Curry',
#  'is_active': True}

# %%
steph_career = playercareerstats.PlayerCareerStats(player_id='201939')
steph_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201939   2009-10        00  1610612744               GSW        22.0
# 1     201939   2010-11        00  1610612744               GSW        23.0
# 2     201939   2011-12        00  1610612744               GSW        24.0
# 3     201939   2012-13        00  1610612744               GSW        25.0
# 4     201939   2013-14        00  1610612744               GSW        26.0
# 5     201939   2014-15        00  1610612744               GSW        27.0
# 6     201939   2015-16        00  1610612744               GSW        28.0
# 7     201939   2016-17        00  1610612744               GSW        29.0
# 8     201939   2017-18        00  1610612744               GSW        30.0
# 9     201939   2018-19        00  1610612744               GSW        31.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
steph_career = steph_career.get_data_frames()[0]
steph_career = steph_career.loc[:, ["PLAYER_ID", "PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
steph_career.head(10)
# Out:
#    PLAYER_ID  PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0     201939        22.0   166   380    0.437
# 1     201939        23.0   151   342    0.442
# 2     201939        24.0    55   121    0.455
# 3     201939        25.0   272   600    0.453
# 4     201939        26.0   261   615    0.424
# 5     201939        27.0   286   646    0.443
# 6     201939        28.0   402   886    0.454
# 7     201939        29.0   324   789    0.411
# 8     201939        30.0   212   501    0.423
# 9     201939        31.0   354   810    0.437

# %%
steph_career.to_csv('Steph_Curry_Career.csv')

# %%
mj = [player for player in nba_players
                   if player['full_name'] == 'Michael Jordan'][0]
mj
# Out:
# {'id': 893,
#  'full_name': 'Michael Jordan',
#  'first_name': 'Michael',
#  'last_name': 'Jordan',
#  'is_active': False}

# %%
mj_career = playercareerstats.PlayerCareerStats(player_id= "893")
mj_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0         893   1984-85        00  1610612741               CHI        22.0
# 1         893   1985-86        00  1610612741               CHI        23.0
# 2         893   1986-87        00  1610612741               CHI        24.0
# 3         893   1987-88        00  1610612741               CHI        25.0
# 4         893   1988-89        00  1610612741               CHI        26.0
# 5         893   1989-90        00  1610612741               CHI        27.0
# 6         893   1990-91        00  1610612741               CHI        28.0
# 7         893   1991-92        00  1610612741               CHI        29.0
# 8         893   1992-93        00  1610612741               CHI        30.0
# 9         893   1994-95        00  1610612741               CHI        32.0
# 10        893   1995-96        00  1610612741               CHI        33.0
# ...

# %%
mj_career = mj_career.get_data_frames()[0]
mj_career = mj_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
mj_career.head(15)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         22.0     9    52    0.173
# 1         23.0     3    18    0.167
# 2         24.0    12    66    0.182
# 3         25.0     7    53    0.132
# 4         26.0    27    98    0.276
# 5         27.0    92   245    0.376
# 6         28.0    29    93    0.312
# 7         29.0    27   100    0.270
# 8         30.0    81   230    0.352
# 9         32.0    16    32    0.500
# 10        33.0   111   260    0.427
# 11        34.0   111   297    0.374
# 12        35.0    30   126    0.238
# 13        39.0    10    53    0.189
# 14        40.0    16    55    0.291

# %%
rubio = [player for player in nba_players
                   if player['full_name'] == 'Ricky Rubio'][0]
rubio
# Out:
# {'id': 201937,
#  'full_name': 'Ricky Rubio',
#  'first_name': 'Ricky',
#  'last_name': 'Rubio',
#  'is_active': True}

# %%
rubio_career = playercareerstats.PlayerCareerStats(player_id= "201937")
rubio_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201937   2011-12        00  1610612750               MIN        21.0
# 1     201937   2012-13        00  1610612750               MIN        22.0
# 2     201937   2013-14        00  1610612750               MIN        23.0
# 3     201937   2014-15        00  1610612750               MIN        24.0
# 4     201937   2015-16        00  1610612750               MIN        25.0
# 5     201937   2016-17        00  1610612750               MIN        26.0
# 6     201937   2017-18        00  1610612762               UTA        27.0
# 7     201937   2018-19        00  1610612762               UTA        28.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  41  31  1404.0  139  ...    0.803    21   150  171  336   91    8  131
# 1  57  47  1691.0  185  ...    0.799    44   185  229  418  137    5  172
# ...

# %%
rubio_career = rubio_career.get_data_frames()[0]
rubio_career = rubio_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
rubio_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    32    94    0.340
# 1        22.0    27    92    0.293
# 2        23.0    44   133    0.331
# 3        24.0    13    51    0.255
# 4        25.0    62   190    0.326
# 5        26.0    60   196    0.306
# 6        27.0    96   273    0.352
# 7        28.0    79   254    0.311

# %%
rubio_career.to_csv('Ricky_Rubio_Career.csv')

# %%
flynn = [player for player in nba_players
                   if player['full_name'] == 'Jonny Flynn'][0]
flynn
# Out:
# {'id': 201938,
#  'full_name': 'Jonny Flynn',
#  'first_name': 'Jonny',
#  'last_name': 'Flynn',
#  'is_active': False}

# %%
flynn_career = playercareerstats.PlayerCareerStats(player_id= "201938")
flynn_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201938   2009-10        00  1610612750               MIN        21.0
# 1     201938   2010-11        00  1610612750               MIN        22.0
# 2     201938   2011-12        00  1610612745               HOU        23.0
# 3     201938   2011-12        00  1610612757               POR        23.0
# 4     201938   2011-12        00           0               TOT        23.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  81  81  2339.0  397  ...    0.826    24   167  191  356   82    2  233  98
# 1  53   8   983.0  108  ...    0.762    12    65   77  182   34    3  113  58
# 2  11   0   135.0   12  ...    0.786     1     7    8   28    3    1    9   8
# 3  18   1   281.0   34  ...    0.720     7    24   31   68    3    1   27  15
# 4  29   1   416.0   46  ...    0.744     8    31   39   96    6    2   36  23
#
#     PTS
# 0  1094
# 1   279
# 2    37
# ...

# %%
flynn_career = flynn_career.get_data_frames()[0]
flynn_career = flynn_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
flynn_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    77   215    0.358
# 1        22.0    31   100    0.310
# 2        23.0     2     9    0.222
# 3        23.0     8    25    0.320
# 4        23.0    10    34    0.294

# %%
flynn_career = flynn_career.drop([2, 3])
flynn_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    77   215    0.358
# 1        22.0    31   100    0.310
# 4        23.0    10    34    0.294

# %%
flynn_career.to_csv('Jonny_Flynn_Career.csv')

# %%
jennings = [player for player in nba_players
                   if player['full_name'] == 'Brandon Jennings'][0]
jennings
# Out:
# {'id': 201943,
#  'full_name': 'Brandon Jennings',
#  'first_name': 'Brandon',
#  'last_name': 'Jennings',
#  'is_active': False}

# %%
jennings_career = playercareerstats.PlayerCareerStats(player_id= "201943")
jennings_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201943   2009-10        00  1610612749               MIL        20.0
# 1      201943   2010-11        00  1610612749               MIL        21.0
# 2      201943   2011-12        00  1610612749               MIL        22.0
# 3      201943   2012-13        00  1610612749               MIL        23.0
# 4      201943   2013-14        00  1610612765               DET        24.0
# 5      201943   2014-15        00  1610612765               DET        25.0
# 6      201943   2015-16        00  1610612765               DET        26.0
# 7      201943   2015-16        00  1610612753               ORL        26.0
# 8      201943   2015-16        00           0               TOT        26.0
# 9      201943   2016-17        00  1610612752               NYK        27.0
# 10     201943   2016-17        00  1610612764               WAS        27.0
# ...

# %%
jennings_career = jennings_career.get_data_frames()[0]
jennings_career = jennings_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
jennings_career.head(15)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         20.0   145   388    0.374
# 1         21.0    98   303    0.323
# 2         22.0   129   388    0.332
# 3         23.0   173   461    0.375
# 4         24.0   154   457    0.337
# 5         25.0    76   211    0.360
# 6         26.0    24    77    0.312
# 7         26.0    27    78    0.346
# 8         26.0    51   155    0.329
# 9         27.0    68   200    0.340
# 10        27.0    11    52    0.212
# 11        27.0    79   252    0.313
# 12        28.0     9    33    0.273

# %%
jennings_career = jennings_career.drop([6, 7, 9, 10])
jennings_career
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         20.0   145   388    0.374
# 1         21.0    98   303    0.323
# 2         22.0   129   388    0.332
# 3         23.0   173   461    0.375
# 4         24.0   154   457    0.337
# 5         25.0    76   211    0.360
# 8         26.0    51   155    0.329
# 11        27.0    79   252    0.313
# 12        28.0     9    33    0.273

# %%
jennings_career.to_csv('Brandon_Jennings_Career.csv')

# %%
holiday = [player for player in nba_players
                   if player['full_name'] == 'Jrue Holiday'][0]
holiday
# Out:
# {'id': 201950,
#  'full_name': 'Jrue Holiday',
#  'first_name': 'Jrue',
#  'last_name': 'Holiday',
#  'is_active': True}

# %%
holiday_career = playercareerstats.PlayerCareerStats(player_id= "201950")
holiday_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201950   2009-10        00  1610612755               PHI        20.0
# 1     201950   2010-11        00  1610612755               PHI        21.0
# 2     201950   2011-12        00  1610612755               PHI        22.0
# 3     201950   2012-13        00  1610612755               PHI        23.0
# 4     201950   2013-14        00  1610612740               NOP        24.0
# 5     201950   2014-15        00  1610612740               NOP        25.0
# 6     201950   2015-16        00  1610612740               NOP        26.0
# 7     201950   2016-17        00  1610612740               NOP        27.0
# 8     201950   2017-18        00  1610612740               NOP        28.0
# 9     201950   2018-19        00  1610612740               NOP        28.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
holiday_career = holiday_career.get_data_frames()[0]
holiday_career = holiday_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
holiday_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    62   159    0.390
# 1        21.0    81   222    0.365
# 2        22.0    65   171    0.380
# 3        23.0    91   247    0.368
# 4        24.0    30    77    0.390
# 5        25.0    51   135    0.378
# 6        26.0    87   259    0.336
# 7        27.0   100   281    0.356
# 8        28.0   120   356    0.337
# 9        28.0   118   363    0.325

# %%
holiday_career.to_csv('Jrue_Holiday_Career.csv')

# %%
lawson = [player for player in nba_players
                   if player['full_name'] == 'Ty Lawson'][0]
lawson
# Out:
# {'id': 201951,
#  'full_name': 'Ty Lawson',
#  'first_name': 'Ty',
#  'last_name': 'Lawson',
#  'is_active': False}

# %%
lawson_career = playercareerstats.PlayerCareerStats(player_id= "201951")
lawson_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201951   2009-10        00  1610612743               DEN        22.0
# 1     201951   2010-11        00  1610612743               DEN        23.0
# 2     201951   2011-12        00  1610612743               DEN        24.0
# 3     201951   2012-13        00  1610612743               DEN        25.0
# 4     201951   2013-14        00  1610612743               DEN        26.0
# 5     201951   2014-15        00  1610612743               DEN        27.0
# 6     201951   2015-16        00  1610612745               HOU        28.0
# 7     201951   2015-16        00  1610612754               IND        28.0
# 8     201951   2015-16        00           0               TOT        28.0
# 9     201951   2016-17        00  1610612758               SAC        29.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
lawson_career = lawson_career.get_data_frames()[0]
lawson_career = lawson_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
lawson_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    34    83    0.410
# 1        23.0    69   171    0.404
# 2        24.0    73   200    0.365
# 3        25.0    85   232    0.366
# 4        26.0    72   202    0.356
# 5        27.0    70   205    0.341
# 6        28.0    31    94    0.330
# 7        28.0     5    14    0.357
# 8        28.0    36   108    0.333
# 9        29.0    34   118    0.288

# %%
lawson_career = lawson_career.drop([6, 7])
lawson_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    34    83    0.410
# 1        23.0    69   171    0.404
# 2        24.0    73   200    0.365
# 3        25.0    85   232    0.366
# 4        26.0    72   202    0.356
# 5        27.0    70   205    0.341
# 8        28.0    36   108    0.333
# 9        29.0    34   118    0.288

# %%
lawson_career.to_csv('Ty_Lawson_Career.csv')

# %%
teague = [player for player in nba_players
                   if player['full_name'] == 'Jeff Teague'][0]
teague
# Out:
# {'id': 201952,
#  'full_name': 'Jeff Teague',
#  'first_name': 'Jeff',
#  'last_name': 'Teague',
#  'is_active': True}

# %%
teague_career = playercareerstats.PlayerCareerStats(player_id= "201952")
teague_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201952   2009-10        00  1610612737               ATL        22.0
# 1     201952   2010-11        00  1610612737               ATL        23.0
# 2     201952   2011-12        00  1610612737               ATL        24.0
# 3     201952   2012-13        00  1610612737               ATL        25.0
# 4     201952   2013-14        00  1610612737               ATL        26.0
# 5     201952   2014-15        00  1610612737               ATL        27.0
# 6     201952   2015-16        00  1610612737               ATL        28.0
# 7     201952   2016-17        00  1610612754               IND        29.0
# 8     201952   2017-18        00  1610612750               MIN        30.0
# 9     201952   2018-19        00  1610612750               MIN        30.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
teague_career = teague_career.get_data_frames()[0]
teague_career = teague_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
teague_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0     7    32    0.219
# 1        23.0    18    48    0.375
# 2        24.0    51   149    0.342
# 3        25.0    89   248    0.359
# 4        26.0    74   225    0.329
# 5        27.0    71   207    0.343
# 6        28.0   110   274    0.401
# 7        29.0    90   252    0.357
# 8        30.0    84   228    0.368
# 9        30.0    35   105    0.333

# %%
teague_career.to_csv('Jeff_Teague_Career.csv')

# %%
Maynor = [player for player in nba_players
                   if player['full_name'] == 'Eric Maynor'][0]
Maynor
# Out:
# {'id': 201953,
#  'full_name': 'Eric Maynor',
#  'first_name': 'Eric',
#  'last_name': 'Maynor',
#  'is_active': False}

# %%
maynor_career = playercareerstats.PlayerCareerStats(player_id= "201953")
maynor_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201953   2009-10        00  1610612762               UTA        23.0
# 1      201953   2009-10        00  1610612760               OKC        23.0
# 2      201953   2009-10        00           0               TOT        23.0
# 3      201953   2010-11        00  1610612760               OKC        24.0
# 4      201953   2011-12        00  1610612760               OKC        25.0
# 5      201953   2012-13        00  1610612760               OKC        26.0
# 6      201953   2012-13        00  1610612757               POR        26.0
# 7      201953   2012-13        00           0               TOT        26.0
# 8      201953   2013-14        00  1610612764               WAS        27.0
# 9      201953   2013-14        00  1610612755               PHI        27.0
# 10     201953   2013-14        00           0               TOT        27.0
#
# ...

# %%
maynor_career = maynor_career.get_data_frames()[0]
maynor_career = maynor_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
maynor_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0     5    24    0.208
# 1        23.0    17    47    0.362
# 2        23.0    22    71    0.310
# 3        24.0    37    96    0.385
# 4        25.0     6    17    0.353
# 5        26.0    15    46    0.326
# 6        26.0    19    50    0.380
# 7        26.0    34    96    0.354
# 8        27.0     8    25    0.320
# 9        27.0     4    12    0.333

# %%
maynor_career = maynor_career.drop([0, 1, 5, 6, 8, 9])
maynor_career
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 2         23.0    22    71    0.310
# 3         24.0    37    96    0.385
# 4         25.0     6    17    0.353
# 7         26.0    34    96    0.354
# 10        27.0    12    37    0.324

# %%
maynor_career.to_csv('Eric_Maynor_Career.csv')

# %%
collison = [player for player in nba_players
                   if player['full_name'] == 'Darren Collison'][0]
collison
# Out:
# {'id': 201954,
#  'full_name': 'Darren Collison',
#  'first_name': 'Darren',
#  'last_name': 'Collison',
#  'is_active': True}

# %%
collison_career = playercareerstats.PlayerCareerStats(player_id= "201954")
collison_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201954   2009-10        00  1610612740               NOH        22.0
# 1     201954   2010-11        00  1610612754               IND        23.0
# 2     201954   2011-12        00  1610612754               IND        24.0
# 3     201954   2012-13        00  1610612742               DAL        25.0
# 4     201954   2013-14        00  1610612746               LAC        26.0
# 5     201954   2014-15        00  1610612758               SAC        27.0
# 6     201954   2015-16        00  1610612758               SAC        28.0
# 7     201954   2016-17        00  1610612758               SAC        29.0
# 8     201954   2017-18        00  1610612754               IND        30.0
# 9     201954   2018-19        00  1610612754               IND        31.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
collison_career = collison_career.get_data_frames()[0]
collison_career = collison_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
collison_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    46   115    0.400
# 1        23.0    41   124    0.331
# 2        24.0    34    94    0.362
# 3        25.0    48   136    0.353
# 4        26.0    71   189    0.376
# 5        27.0    60   161    0.373
# 6        28.0    87   217    0.401
# 7        29.0    73   175    0.417
# 8        30.0    96   205    0.468
# 9        31.0    79   194    0.407

# %%
collison_career.to_csv('Darren_Collison_Career.csv')

# %%
roddy = [player for player in nba_players
                   if player['full_name'] == 'Rodrigue Beaubois'][0]
roddy
# Out:
# {'id': 201958,
#  'full_name': 'Rodrigue Beaubois',
#  'first_name': 'Rodrigue',
#  'last_name': 'Beaubois',
#  'is_active': False}

# %%
roddy_career = playercareerstats.PlayerCareerStats(player_id= "201958")
roddy_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     201958   2009-10        00  1610612742               DAL        22.0
# 1     201958   2010-11        00  1610612742               DAL        23.0
# 2     201958   2011-12        00  1610612742               DAL        24.0
# 3     201958   2012-13        00  1610612742               DAL        25.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  56  16   700.0  155 ...    0.808    12    66   78   74   29   12   54  84
# 1  28  26   496.0   94 ...    0.767     7    45   52   64   20    8   47  76
# 2  53  12  1151.0  188 ...    0.841    19   132  151  152   56   28   70  98
# 3  45   0   549.0   65 ...    0.789     9    48   57   84   19    4   33  54
#
#    PTS
# 0  397
# 1  236
# 2  472
# 3  181
#
# [4 rows x 27 columns]

# %%
roddy_career = roddy_career.get_data_frames()[0]
roddy_career = roddy_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
roddy_career.head(10)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    45   110    0.409
# 1        23.0    25    83    0.301
# 2        24.0    38   132    0.288
# 3        25.0    21    72    0.292

# %%
roddy_career.to_csv('Roddy_Beaubois_Career.csv')

# %%
douglas = [player for player in nba_players
                   if player['full_name'] == 'Toney Douglas'][0]
douglas
# Out:
# {'id': 201962,
#  'full_name': 'Toney Douglas',
#  'first_name': 'Toney',
#  'last_name': 'Douglas',
#  'is_active': False}

# %%
douglas_career = playercareerstats.PlayerCareerStats(player_id= "201962")
douglas_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201962   2009-10        00  1610612752               NYK        24.0
# 1      201962   2010-11        00  1610612752               NYK        25.0
# 2      201962   2011-12        00  1610612752               NYK        26.0
# 3      201962   2012-13        00  1610612745               HOU        27.0
# 4      201962   2012-13        00  1610612758               SAC        27.0
# 5      201962   2012-13        00           0               TOT        27.0
# 6      201962   2013-14        00  1610612744               GSW        28.0
# 7      201962   2013-14        00  1610612748               MIA        28.0
# 8      201962   2013-14        00           0               TOT        28.0
# 9      201962   2014-15        00  1610612740               NOP        29.0
# 10     201962   2015-16        00  1610612740               NOP        30.0
# ...

# %%
douglas_career = douglas_career.get_data_frames()[0]
douglas_career = douglas_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
douglas_career.head(12)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         24.0    68   175    0.389
# 1         25.0   143   383    0.373
# 2         26.0    27   117    0.231
# 3         27.0    61   162    0.377
# 4         27.0    21    54    0.389
# 5         27.0    82   216    0.380
# 6         28.0    19    59    0.322
# 7         28.0    12    43    0.279
# 8         28.0    31   102    0.304
# 9         29.0     5    18    0.278
# 10        30.0    81   203    0.399
# 11        31.0     7    42    0.167

# %%
douglas_career = douglas_career.drop([3, 4, 6, 7])
douglas_career
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         24.0    68   175    0.389
# 1         25.0   143   383    0.373
# 2         26.0    27   117    0.231
# 5         27.0    82   216    0.380
# 8         28.0    31   102    0.304
# 9         29.0     5    18    0.278
# 10        30.0    81   203    0.399
# 11        31.0     7    42    0.167

# %%
douglas_career.to_csv('Toney_Douglas_Career.csv')

# %%
wall = [player for player in nba_players
                   if player['full_name'] == 'John Wall'][0]
wall
# Out:
# {'id': 202322,
#  'full_name': 'John Wall',
#  'first_name': 'John',
#  'last_name': 'Wall',
#  'is_active': True}

# %%
wall_career = playercareerstats.PlayerCareerStats(player_id= "202322")
wall_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202322   2010-11        00  1610612764               WAS        20.0
# 1     202322   2011-12        00  1610612764               WAS        21.0
# 2     202322   2012-13        00  1610612764               WAS        22.0
# 3     202322   2013-14        00  1610612764               WAS        23.0
# 4     202322   2014-15        00  1610612764               WAS        24.0
# 5     202322   2015-16        00  1610612764               WAS        25.0
# 6     202322   2016-17        00  1610612764               WAS        26.0
# 7     202322   2017-18        00  1610612764               WAS        27.0
# 8     202322   2018-19        00  1610612764               WAS        28.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  69  64  2606.0  398  ...    0.766    35   282  317  574  121   35  261
# ...

# %%
wall_career = wall_career.get_data_frames()[0]
wall_career = wall_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
wall_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    34   115    0.296
# 1        21.0     3    42    0.071
# 2        22.0    12    45    0.267
# 3        23.0   108   308    0.351
# 4        24.0    65   217    0.300
# 5        25.0   115   328    0.351
# 6        26.0    89   272    0.327
# 7        27.0    62   167    0.371
# 8        28.0    51   169    0.302

# %%
wall_career.to_csv('John_Wall_Career.csv')

# %%
bledsoe = [player for player in nba_players
                   if player['full_name'] == 'Eric Bledsoe'][0]
bledsoe
# Out:
# {'id': 202339,
#  'full_name': 'Eric Bledsoe',
#  'first_name': 'Eric',
#  'last_name': 'Bledsoe',
#  'is_active': True}

# %%
bledsoe_career = playercareerstats.PlayerCareerStats(player_id= "202339")
bledsoe_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      202339   2010-11        00  1610612746               LAC        21.0
# 1      202339   2011-12        00  1610612746               LAC        22.0
# 2      202339   2012-13        00  1610612746               LAC        23.0
# 3      202339   2013-14        00  1610612756               PHX        24.0
# 4      202339   2014-15        00  1610612756               PHX        25.0
# 5      202339   2015-16        00  1610612756               PHX        26.0
# 6      202339   2016-17        00  1610612756               PHX        27.0
# 7      202339   2017-18        00  1610612756               PHX        28.0
# 8      202339   2017-18        00  1610612749               MIL        28.0
# 9      202339   2017-18        00           0               TOT        28.0
# 10     202339   2018-19        00  1610612749               MIL        29.0
#
# ...

# %%
bledsoe_career = bledsoe_career.get_data_frames()[0]
bledsoe_career = bledsoe_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
bledsoe_career.head(12)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         21.0    32   116    0.276
# 1         22.0     6    30    0.200
# 2         23.0    31    78    0.397
# 3         24.0    50   140    0.357
# 4         25.0    88   272    0.324
# 5         26.0    48   129    0.372
# 6         27.0   104   310    0.335
# 7         28.0     4    13    0.308
# 8         28.0   121   347    0.349
# 9         28.0   125   360    0.347
# 10        29.0   124   377    0.329

# %%
bledsoe_career = bledsoe_career.drop([7, 8])
bledsoe_career
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         21.0    32   116    0.276
# 1         22.0     6    30    0.200
# 2         23.0    31    78    0.397
# 3         24.0    50   140    0.357
# 4         25.0    88   272    0.324
# 5         26.0    48   129    0.372
# 6         27.0   104   310    0.335
# 9         28.0   125   360    0.347
# 10        29.0   124   377    0.329

# %%
bledsoe_career.to_csv('Eric_Bledsoe_Career.csv')

# %%
vasquez = [player for player in nba_players
                   if player['full_name'] == 'Greivis Vasquez'][0]
vasquez
# Out:
# {'id': 202349,
#  'full_name': 'Greivis Vasquez',
#  'first_name': 'Greivis',
#  'last_name': 'Vasquez',
#  'is_active': False}

# %%
vasquez_career = playercareerstats.PlayerCareerStats(player_id= "202349")
vasquez_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202349   2010-11        00  1610612763               MEM        24.0
# 1     202349   2011-12        00  1610612740               NOH        25.0
# 2     202349   2012-13        00  1610612740               NOH        26.0
# 3     202349   2013-14        00  1610612758               SAC        27.0
# 4     202349   2013-14        00  1610612761               TOR        27.0
# 5     202349   2013-14        00           0               TOT        27.0
# 6     202349   2014-15        00  1610612761               TOR        28.0
# 7     202349   2015-16        00  1610612749               MIL        29.0
# 8     202349   2016-17        00  1610612751               BKN        30.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  70   1   860.0   95  ...    0.773    12    61   73  151   22    4   70
# ...

# %%
vasquez_career = vasquez_career.get_data_frames()[0]
vasquez_career = vasquez_career.loc[:, ["PLAYER_AGE","FG3M", "FG3A", "FG3_PCT"]]
vasquez_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        24.0    25    86    0.291
# 1        25.0    43   135    0.319
# 2        26.0    83   243    0.342
# 3        27.0    16    50    0.320
# 4        27.0    93   239    0.389
# 5        27.0   109   289    0.377
# 6        28.0   133   351    0.379
# 7        29.0    18    73    0.247
# 8        30.0     1     3    0.333

# %%
vasquez_career = vasquez_career.drop([3, 4])
vasquez_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        24.0    25    86    0.291
# 1        25.0    43   135    0.319
# 2        26.0    83   243    0.342
# 5        27.0   109   289    0.377
# 6        28.0   133   351    0.379
# 7        29.0    18    73    0.247
# 8        30.0     1     3    0.333

# %%
vasquez_career.to_csv('Greivis_Vasquez_Career.csv')

# %%
kyrie = [player for player in nba_players
                   if player['full_name'] == 'Kyrie Irving'][0]
kyrie
# Out:
# {'id': 202681,
#  'full_name': 'Kyrie Irving',
#  'first_name': 'Kyrie',
#  'last_name': 'Irving',
#  'is_active': True}

# %%
kyrie_career = playercareerstats.PlayerCareerStats(player_id= "202681")
kyrie_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202681   2011-12        00  1610612739               CLE        20.0
# 1     202681   2012-13        00  1610612739               CLE        21.0
# 2     202681   2013-14        00  1610612739               CLE        22.0
# 3     202681   2014-15        00  1610612739               CLE        23.0
# 4     202681   2015-16        00  1610612739               CLE        24.0
# 5     202681   2016-17        00  1610612739               CLE        25.0
# 6     202681   2017-18        00  1610612738               BOS        26.0
# 7     202681   2018-19        00  1610612738               BOS        27.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  51  51  1558.0  350  ...    0.872    44   147  191  275   54   20  160
# 1  59  59  2048.0  484  ...    0.855    34   182  216  350   89   21  191
# ...

# %%
kyrie_career = kyrie_career.get_data_frames()[0]
kyrie_career = kyrie_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
kyrie_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    73   183    0.399
# 1        21.0   109   279    0.391
# 2        22.0   123   344    0.358
# 3        23.0   157   378    0.415
# 4        24.0    84   262    0.321
# 5        25.0   177   441    0.401
# 6        26.0   166   407    0.408
# 7        27.0   174   434    0.401

# %%
kyrie_career.to_csv('Kyrie_Irving_Career.csv')

# %%
knight = [player for player in nba_players
                   if player['full_name'] == 'Brandon Knight'][0]
knight
# Out:
# {'id': 202688,
#  'full_name': 'Brandon Knight',
#  'first_name': 'Brandon',
#  'last_name': 'Knight',
#  'is_active': True}

# %%
knight_career = playercareerstats.PlayerCareerStats(player_id= "202688")
knight_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      202688   2011-12        00  1610612765               DET        20.0
# 1      202688   2012-13        00  1610612765               DET        21.0
# 2      202688   2013-14        00  1610612749               MIL        22.0
# 3      202688   2014-15        00  1610612749               MIL        23.0
# 4      202688   2014-15        00  1610612756               PHX        23.0
# 5      202688   2014-15        00           0               TOT        23.0
# 6      202688   2015-16        00  1610612756               PHX        24.0
# 7      202688   2016-17        00  1610612756               PHX        25.0
# 8      202688   2018-19        00  1610612745               HOU        27.0
# 9      202688   2018-19        00  1610612739               CLE        27.0
# 10     202688   2018-19        00           0               TOT        27.0
#
# ...

# %%
knight_career = knight_career.get_data_frames()[0]
knight_career = knight_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
knight_career.head(12)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         20.0   105   276    0.380
# 1         21.0   120   327    0.367
# 2         22.0   110   338    0.325
# 3         23.0   104   254    0.409
# 4         23.0    21    67    0.313
# 5         23.0   125   321    0.389
# 6         24.0   120   351    0.342
# 7         25.0    45   139    0.324
# 8         27.0     5    32    0.156
# 9         27.0    36    97    0.371
# 10        27.0    41   129    0.318

# %%
knight_career = knight_career.drop([3, 4, 8, 9])
knight_career
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         20.0   105   276    0.380
# 1         21.0   120   327    0.367
# 2         22.0   110   338    0.325
# 5         23.0   125   321    0.389
# 6         24.0   120   351    0.342
# 7         25.0    45   139    0.324
# 10        27.0    41   129    0.318

# %%
knight_career.to_csv('Brandon_Knight_Career.csv')

# %%
Jimmer = [player for player in nba_players
                   if player['full_name'] == 'Jimmer Fredette'][0]
Jimmer
# Out:
# {'id': 202690,
#  'full_name': 'Jimmer Fredette',
#  'first_name': 'Jimmer',
#  'last_name': 'Fredette',
#  'is_active': True}

# %%
jimmer_career = playercareerstats.PlayerCareerStats(player_id= "202690")
jimmer_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202690   2011-12        00  1610612758               SAC        23.0
# 1     202690   2012-13        00  1610612758               SAC        24.0
# 2     202690   2013-14        00  1610612758               SAC        25.0
# 3     202690   2013-14        00  1610612741               CHI        25.0
# 4     202690   2013-14        00           0               TOT        25.0
# 5     202690   2014-15        00  1610612740               NOP        26.0
# 6     202690   2015-16        00  1610612740               NOP        27.0
# 7     202690   2015-16        00  1610612752               NYK        27.0
# 8     202690   2015-16        00           0               TOT        27.0
# 9     202690   2018-19        00  1610612756               PHX        30.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# ...

# %%
jimmer_career = jimmer_career.get_data_frames()[0]
jimmer_career = jimmer_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
jimmer_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    78   216    0.361
# 1        24.0    65   156    0.417
# 2        25.0    36    73    0.493
# 3        25.0     4    11    0.364
# 4        25.0    40    84    0.476
# 5        26.0     9    48    0.188
# 6        27.0     0     1    0.000
# 7        27.0     1     1    1.000
# 8        27.0     1     2    0.500
# 9        30.0     0    13    0.000

# %%
jimmer_career = jimmer_career.drop([2, 3, 6, 7])
jimmer_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    78   216    0.361
# 1        24.0    65   156    0.417
# 4        25.0    40    84    0.476
# 5        26.0     9    48    0.188
# 8        27.0     1     2    0.500
# 9        30.0     0    13    0.000

# %%
jimmer_career.to_csv('Jimmer_Fredette_Career.csv')

# %%
Nolan = [player for player in nba_players
                   if player['full_name'] == 'Nolan Smith'][0]
Nolan
# Out:
# {'id': 202701,
#  'full_name': 'Nolan Smith',
#  'first_name': 'Nolan',
#  'last_name': 'Smith',
#  'is_active': False}

# %%
nolan_career = playercareerstats.PlayerCareerStats(player_id= "202701")
nolan_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202701   2011-12        00  1610612757               POR        23.0
# 1     202701   2012-13        00  1610612757               POR        24.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  44   4  541.0   67 ...    0.714    17    39   56   62   18    3   42  55
# 1  40   0  288.0   42 ...    0.714     7    20   27   35    7    1   29  26
#
#    PTS
# 0  167
# 1  110
#
# [2 rows x 27 columns]

# %%
nolan_career = nolan_career.get_data_frames()[0]
nolan_career = nolan_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
nolan_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    13    45    0.289
# 1        24.0     6    28    0.214

# %%
nolan_career.to_csv('Nolan_Smith_Career.csv')

# %%
Jackson = [player for player in nba_players
                   if player['full_name'] == 'Reggie Jackson'][0]
Jackson
# Out:
# {'id': 202704,
#  'full_name': 'Reggie Jackson',
#  'first_name': 'Reggie',
#  'last_name': 'Jackson',
#  'is_active': True}

# %%
rj_career = playercareerstats.PlayerCareerStats(player_id= "202704")
rj_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202704   2011-12        00  1610612760               OKC        22.0
# 1     202704   2012-13        00  1610612760               OKC        23.0
# 2     202704   2013-14        00  1610612760               OKC        24.0
# 3     202704   2014-15        00  1610612760               OKC        25.0
# 4     202704   2014-15        00  1610612765               DET        25.0
# 5     202704   2014-15        00           0               TOT        25.0
# 6     202704   2015-16        00  1610612765               DET        26.0
# 7     202704   2016-17        00  1610612765               DET        27.0
# 8     202704   2017-18        00  1610612765               DET        28.0
# 9     202704   2018-19        00  1610612765               DET        29.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
rj_career = rj_career.get_data_frames()[0]
rj_career = rj_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
rj_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    13    62    0.210
# 1        23.0    24   104    0.231
# 2        24.0    83   245    0.339
# 3        25.0    44   158    0.278
# 4        25.0    28    83    0.337
# 5        25.0    72   241    0.299
# 6        26.0   118   334    0.353
# 7        27.0    66   184    0.359
# 8        28.0    52   169    0.308
# 9        29.0   174   471    0.369

# %%
rj_career = rj_career.drop([3, 4])
rj_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    13    62    0.210
# 1        23.0    24   104    0.231
# 2        24.0    83   245    0.339
# 5        25.0    72   241    0.299
# 6        26.0   118   334    0.353
# 7        27.0    66   184    0.359
# 8        28.0    52   169    0.308
# 9        29.0   174   471    0.369

# %%
rj_career.to_csv('Reggie_Jackson_Career.csv')

# %%
Norris = [player for player in nba_players
                   if player['full_name'] == 'Norris Cole'][0]
Norris
# Out:
# {'id': 202708,
#  'full_name': 'Norris Cole',
#  'first_name': 'Norris',
#  'last_name': 'Cole',
#  'is_active': False}

# %%
norris_career = playercareerstats.PlayerCareerStats(player_id= "202708")
norris_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202708   2011-12        00  1610612748               MIA        23.0
# 1     202708   2012-13        00  1610612748               MIA        24.0
# 2     202708   2013-14        00  1610612748               MIA        25.0
# 3     202708   2014-15        00  1610612748               MIA        26.0
# 4     202708   2014-15        00  1610612740               NOP        26.0
# 5     202708   2014-15        00           0               TOT        26.0
# 6     202708   2015-16        00  1610612740               NOP        27.0
# 7     202708   2016-17        00  1610612760               OKC        28.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  65   2  1260.0  177 ...    0.776    21    70   91  133   44    2  105  124
# 1  80   4  1590.0  179 ...    0.650    18   112  130  164   57    7  104  155
# ...

# %%
norris_career = norris_career.get_data_frames()[0]
norris_career = norris_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
norris_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    21    76    0.276
# 1        24.0    35    98    0.357
# 2        25.0    60   174    0.345
# 3        26.0    27   102    0.265
# 4        26.0    28    74    0.378
# 5        26.0    55   176    0.313
# 6        27.0    33   102    0.324
# 7        28.0     3    13    0.231

# %%
norris_career = norris_career.drop([3, 4])
norris_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    21    76    0.276
# 1        24.0    35    98    0.357
# 2        25.0    60   174    0.345
# 5        26.0    55   176    0.313
# 6        27.0    33   102    0.324
# 7        28.0     3    13    0.231

# %%
norris_career.to_csv('Norris_Cole_Career.csv')

# %%
Cojo = [player for player in nba_players
                   if player['full_name'] == 'Cory Joseph'][0]
Cojo
# Out:
# {'id': 202709,
#  'full_name': 'Cory Joseph',
#  'first_name': 'Cory',
#  'last_name': 'Joseph',
#  'is_active': True}

# %%
cojo_career = playercareerstats.PlayerCareerStats(player_id= "202709")
cojo_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202709   2011-12        00  1610612759               SAS        20.0
# 1     202709   2012-13        00  1610612759               SAS        21.0
# 2     202709   2013-14        00  1610612759               SAS        22.0
# 3     202709   2014-15        00  1610612759               SAS        23.0
# 4     202709   2015-16        00  1610612761               TOR        24.0
# 5     202709   2016-17        00  1610612761               TOR        25.0
# 6     202709   2017-18        00  1610612754               IND        26.0
# 7     202709   2018-19        00  1610612754               IND        27.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  29   1   266.0   22 ...    0.647     5    20   25   34    7    3   12   16
# 1  28   9   388.0   51 ...    0.857    12    40   52   53   15    4   21   25
# ...

# %%
cojo_career = cojo_career.get_data_frames()[0]
cojo_career = cojo_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
cojo_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     3    15    0.200
# 1        21.0     6    21    0.286
# 2        22.0    12    38    0.316
# 3        23.0    16    44    0.364
# 4        24.0    30   110    0.273
# 5        25.0    48   135    0.356
# 6        26.0    67   190    0.353
# 7        27.0    55   171    0.322

# %%
cojo_career.to_csv('Cory_Joseph_Career.csv')

# %%
KMarsh = [player for player in nba_players
                   if player['full_name'] == 'Kendall Marshall'][0]
KMarsh
# Out:
# {'id': 203088,
#  'full_name': 'Kendall Marshall',
#  'first_name': 'Kendall',
#  'last_name': 'Marshall',
#  'is_active': False}

# %%
KMarsh_career = playercareerstats.PlayerCareerStats(player_id= "203088")
KMarsh_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203088   2012-13        00  1610612756               PHX        21.0
# 1     203088   2013-14        00  1610612747               LAL        22.0
# 2     203088   2014-15        00  1610612749               MIL        23.0
# 3     203088   2015-16        00  1610612755               PHI        24.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  48   3   702.0   56 ...    0.571     4    38   42  143   22    4   57  48
# 1  54  45  1564.0  170 ...    0.528    15   140  155  477   48    4  150  76
# 2  28   3   417.0   46 ...    0.889     2    26   28   86   21    0   35  26
# 3  30   6   400.0   43 ...    0.692     2    26   28   73   16    2   43  30
#
#    PTS
# 0  143
# 1  430
# 2  118
# 3  111
#
# [4 rows x 27 columns]

# %%
KMarsh_career = KMarsh_career.get_data_frames()[0]
KMarsh_career = KMarsh_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
KMarsh_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    23    73    0.315
# 1        22.0    71   178    0.399
# 2        23.0    18    46    0.391
# 3        24.0    16    49    0.327

# %%
KMarsh_career.to_csv('Kendall_Marshall_Career.csv')

# %%
Wroten = [player for player in nba_players
                   if player['full_name'] == 'Tony Wroten'][0]
Wroten
# Out:
# {'id': 203100,
#  'full_name': 'Tony Wroten',
#  'first_name': 'Tony',
#  'last_name': 'Wroten',
#  'is_active': False}

# %%
Wroten_career = playercareerstats.PlayerCareerStats(player_id= "203100")
Wroten_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203100   2012-13        00  1610612763               MEM        20.0
# 1     203100   2013-14        00  1610612755               PHI        21.0
# 2     203100   2014-15        00  1610612755               PHI        22.0
# 3     203100   2015-16        00  1610612755               PHI        23.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  35   0   272.0   33 ...    0.724    13    15   28   43    8    4   29   34
# 1  72  16  1765.0  345 ...    0.641    69   159  228  217   78   16  204  151
# 2  30  15   895.0  175 ...    0.667    22    64   86  157   48    8  113   72
# 3   8   3   144.0   22 ...    0.541     2    19   21   20    3    0   29   11
#
#    PTS
# 0   91
# 1  939
# 2  507
# 3   67
#
# [4 rows x 27 columns]

# %%
Wroten_career = Wroten_career.get_data_frames()[0]
Wroten_career = Wroten_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Wroten_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     4    16    0.250
# 1        21.0    40   188    0.213
# 2        22.0    37   142    0.261
# 3        23.0     3    17    0.176

# %%
Wroten_career.to_csv('Tony_Wroten_Career.csv')

# %%
LilTeague = [player for player in nba_players
                   if player['full_name'] == 'Marquis Teague'][0]
LilTeague
# Out:
# {'id': 203104,
#  'full_name': 'Marquis Teague',
#  'first_name': 'Marquis',
#  'last_name': 'Teague',
#  'is_active': False}

# %%
LilTeague_career = playercareerstats.PlayerCareerStats(player_id= "203104")
LilTeague_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203104   2012-13        00  1610612741               CHI        20.0
# 1     203104   2013-14        00  1610612741               CHI        21.0
# 2     203104   2013-14        00  1610612751               BKN        21.0
# 3     203104   2013-14        00           0               TOT        21.0
# 4     203104   2017-18        00  1610612763               MEM        25.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  48   0  392.0   43 ...    0.563     3    41   44   63    9    7   35  47
# 1  19   2  242.0   16 ...    0.688     1    18   19   28    2    4   17  25
# 2  21   1  201.0   22 ...    0.789     0    21   21   30    8    1   22  21
# 3  40   3  442.0   38 ...    0.743     1    39   40   58   10    5   39  46
# 4   3   0   74.0    4 ...    0.400     1     5    6   13    4    0    3   5
#
#    PTS
# 0   99
# 1   45
# 2   62
# 3  107
# 4   11
#
# ...

# %%
LilTeague_career = LilTeague_career.get_data_frames()[0]
LilTeague_career = LilTeague_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
LilTeague_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     4    23    0.174
# 1        21.0     2    10    0.200
# 2        21.0     3     8    0.375
# 3        21.0     5    18    0.278
# 4        25.0     1     4    0.250

# %%
LilTeague_career = LilTeague_career.drop([1, 2])
LilTeague_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     4    23    0.174
# 3        21.0     5    18    0.278
# 4        25.0     1     4    0.250

# %%
LilTeague_career.to_csv('Marquis_Teague_Career.csv')

# %%
Burke = [player for player in nba_players
                   if player['full_name'] == 'Trey Burke'][0]
Burke
# Out:
# {'id': 203504,
#  'full_name': 'Trey Burke',
#  'first_name': 'Trey',
#  'last_name': 'Burke',
#  'is_active': True}

# %%
Burke_career = playercareerstats.PlayerCareerStats(player_id= "203504")
Burke_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203504   2013-14        00  1610612762               UTA        21.0
# 1     203504   2014-15        00  1610612762               UTA        22.0
# 2     203504   2015-16        00  1610612762               UTA        23.0
# 3     203504   2016-17        00  1610612764               WAS        24.0
# 4     203504   2017-18        00  1610612752               NYK        25.0
# 5     203504   2018-19        00  1610612752               NYK        26.0
# 6     203504   2018-19        00  1610612742               DAL        26.0
# 7     203504   2018-19        00           0               TOT        26.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  70  68  2262.0  341 ...    0.903    37   171  208  396   42    6  131  145
# 1  76  43  2288.0  370 ...    0.752    31   173  204  328   65   15  124  119
# ...

# %%
Burke_career = Burke_career.get_data_frames()[0]
Burke_career = Burke_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Burke_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0   111   336    0.330
# 1        22.0   124   390    0.318
# 2        23.0    88   256    0.344
# 3        24.0    31    70    0.443
# 4        25.0    38   105    0.362
# 5        26.0    30    86    0.349
# 6        26.0    26    73    0.356
# 7        26.0    56   159    0.352

# %%
Burke_career = Burke_career.drop([5, 6])
Burke_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0   111   336    0.330
# 1        22.0   124   390    0.318
# 2        23.0    88   256    0.344
# 3        24.0    31    70    0.443
# 4        25.0    38   105    0.362
# 7        26.0    56   159    0.352

# %%
Burke_career.to_csv('Trey_Burke_Career.csv')

# %%
MCW = [player for player in nba_players
                   if player['full_name'] == 'Michael Carter-Williams'][0]
MCW
# Out:
# {'id': 203487,
#  'full_name': 'Michael Carter-Williams',
#  'first_name': 'Michael',
#  'last_name': 'Carter-Williams',
#  'is_active': True}

# %%
MCW_career = playercareerstats.PlayerCareerStats(player_id= "203487")
MCW_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203487   2013-14        00  1610612755               PHI        22.0
# 1     203487   2014-15        00  1610612755               PHI        23.0
# 2     203487   2014-15        00  1610612749               MIL        23.0
# 3     203487   2014-15        00           0               TOT        23.0
# 4     203487   2015-16        00  1610612749               MIL        24.0
# 5     203487   2016-17        00  1610612741               CHI        25.0
# 6     203487   2017-18        00  1610612766               CHA        26.0
# 7     203487   2018-19        00  1610612745               HOU        27.0
# 8     203487   2018-19        00  1610612753               ORL        27.0
# 9     203487   2018-19        00           0               TOT        27.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %%
MCW_career = MCW_career.get_data_frames()[0]
MCW_career = MCW_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
MCW_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    55   208    0.264
# 1        23.0    32   125    0.256
# 2        23.0     4    28    0.143
# 3        23.0    36   153    0.235
# 4        24.0    15    55    0.273
# 5        25.0    15    64    0.234
# 6        26.0    14    59    0.237
# 7        27.0     7    19    0.368
# 8        27.0     3    19    0.158
# 9        27.0    10    38    0.263

# %%
MCW_career = MCW_career.drop([1, 2, 7, 8])
MCW_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    55   208    0.264
# 3        23.0    36   153    0.235
# 4        24.0    15    55    0.273
# 5        25.0    15    64    0.234
# 6        26.0    14    59    0.237
# 9        27.0    10    38    0.263

# %%
MCW_career.to_csv('MCW_Career.csv')

# %%
Schroder = [player for player in nba_players
                   if player['full_name'] == 'Dennis Schroder'][0]
Schroder
# Out:
# {'id': 203471,
#  'full_name': 'Dennis Schroder',
#  'first_name': 'Dennis',
#  'last_name': 'Schroder',
#  'is_active': True}

# %%
Schroder_career = playercareerstats.PlayerCareerStats(player_id= "203471")
Schroder_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203471   2013-14        00  1610612737               ATL        20.0
# 1     203471   2014-15        00  1610612737               ATL        21.0
# 2     203471   2015-16        00  1610612737               ATL        22.0
# 3     203471   2016-17        00  1610612737               ATL        23.0
# 4     203471   2017-18        00  1610612737               ATL        24.0
# 5     203471   2018-19        00  1610612760               OKC        25.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  49   0   641.0   72  ...    0.674     5    55   60   93   17    0   61
# 1  77  10  1516.0  284  ...    0.827    29   135  164  317   49    4  150
# 2  80   6  1621.0  329  ...    0.791    25   179  204  349   70    9  183
# 3  79  78  2485.0  548  ...    0.855    42   206  248  499   74   16  258
# ...

# %%
Schroder_career = Schroder_career.get_data_frames()[0]
Schroder_career = Schroder_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Schroder_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    10    42    0.238
# 1        21.0    52   148    0.351
# 2        22.0    77   239    0.322
# 3        23.0   100   294    0.340
# 4        24.0    76   262    0.290
# 5        25.0   124   364    0.341

# %%
Schroder_career.to_csv('Dennis_Schroder_Career.csv')

# %%
Larkin = [player for player in nba_players
                   if player['full_name'] == 'Shane Larkin'][0]
Larkin
# Out:
# {'id': 203499,
#  'full_name': 'Shane Larkin',
#  'first_name': 'Shane',
#  'last_name': 'Larkin',
#  'is_active': False}

# %%
Larkin_career = playercareerstats.PlayerCareerStats(player_id= "203499")
Larkin_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203499   2013-14        00  1610612742               DAL        21.0
# 1     203499   2014-15        00  1610612752               NYK        22.0
# 2     203499   2015-16        00  1610612751               BKN        23.0
# 3     203499   2017-18        00  1610612738               BOS        25.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  48   0   489.0   52 ...    0.640    11    31   42   71   26    1   39   46
# 1  76  22  1865.0  187 ...    0.782    29   147  176  226   93    9   83  150
# 2  78  17  1751.0  222 ...    0.776    28   152  180  342   95   12  146  121
# 3  54   2   775.0   84 ...    0.865    15    77   92   98   29    2   33   58
#
#    PTS
# 0  132
# 1  470
# 2  566
# 3  231
#
# [4 rows x 27 columns]

# %%
Larkin_career = Larkin_career.get_data_frames()[0]
Larkin_career = Larkin_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Larkin_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    12    38    0.316
# 1        22.0    35   116    0.302
# 2        23.0    39   108    0.361
# 3        25.0    31    86    0.360

# %%
Larkin_career.to_csv('Shane_Larkin_Career.csv')

# %%
Nedovic = [player for player in nba_players
                   if player['full_name'] == 'Nemanja Nedovic'][0]
Nedovic
# Out:
# {'id': 203517,
#  'full_name': 'Nemanja Nedovic',
#  'first_name': 'Nemanja',
#  'last_name': 'Nedovic',
#  'is_active': False}

# %%
Nedovic_career = playercareerstats.PlayerCareerStats(player_id= "203517")
Nedovic_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203517   2013-14        00  1610612744               GSW        23.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  24   0  142.0    8 ...    0.875     3    12   15   13    0    1   13  13
#
#    PTS
# 0   26
#
# [1 rows x 27 columns]

# %%
Nedovic_career = Nedovic_career.get_data_frames()[0]
Nedovic_career = Nedovic_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Nedovic_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0     3    18    0.167

# %%
Nedovic_career.to_csv('Nemanja_Nedovic_Career.csv')

# %%
Exum = [player for player in nba_players
                   if player['full_name'] == 'Dante Exum'][0]
Exum
# Out:
# {'id': 203957,
#  'full_name': 'Dante Exum',
#  'first_name': 'Dante',
#  'last_name': 'Exum',
#  'is_active': True}

# %%
Exum_career = playercareerstats.PlayerCareerStats(player_id= "203957")
Exum_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203957   2014-15        00  1610612762               UTA        19.0
# 1     203957   2016-17        00  1610612762               UTA        21.0
# 2     203957   2017-18        00  1610612762               UTA        22.0
# 3     203957   2018-19        00  1610612762               UTA        23.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  82  41  1817.0  145 ...    0.625    27   104  131  198   41   14  118  147
# 1  66  26  1228.0  155 ...    0.795    30   102  132  111   21   12   80  146
# 2  14   0   235.0   42 ...    0.806     4    22   26   43    8    3   20   20
# 3  42   1   664.0  101 ...    0.791    16    52   68  110   14    5   52   69
#
#    PTS
# 0  393
# 1  412
# 2  114
# 3  288
#
# [4 rows x 27 columns]

# %%
Exum_career = Exum_career.get_data_frames()[0]
Exum_career = Exum_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Exum_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        19.0    83   264    0.314
# 1        21.0    44   149    0.295
# 2        22.0     5    18    0.278
# 3        23.0    18    62    0.290

# %%
Exum_career.to_csv('Dante_Exum_Career.csv')

# %%
Smart = [player for player in nba_players
                   if player['full_name'] == 'Marcus Smart'][0]
Smart
# Out:
# {'id': 203935,
#  'full_name': 'Marcus Smart',
#  'first_name': 'Marcus',
#  'last_name': 'Smart',
#  'is_active': True}

# %%
Smart_career = playercareerstats.PlayerCareerStats(player_id= "203935")
Smart_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203935   2014-15        00  1610612738               BOS        21.0
# 1     203935   2015-16        00  1610612738               BOS        22.0
# 2     203935   2016-17        00  1610612738               BOS        23.0
# 3     203935   2017-18        00  1610612738               BOS        24.0
# 4     203935   2018-19        00  1610612738               BOS        25.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  67  38  1808.0  175 ...    0.646    61   161  222  208   99   18   90  176
# 1  61  10  1667.0  184 ...    0.777    76   179  255  185   91   18   80  183
# 2  79  24  2399.0  269 ...    0.812    78   227  305  364  125   34  159  192
# 3  54  11  1614.0  189 ...    0.729    43   145  188  259   71   23  129  133
# 4  80  60  2200.0  239 ...    0.806    57   177  234  321  143   28  123  201
#
#    PTS
# 0  523
# 1  558
# 2  835
# 3  550
# ...

# %%
Smart_career = Smart_career.get_data_frames()[0]
Smart_career = Smart_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Smart_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    91   272    0.335
# 1        22.0    61   241    0.253
# 2        23.0    94   332    0.283
# 3        24.0    75   249    0.301
# 4        25.0   126   346    0.364

# %%
Smart_career.to_csv('Marcus_Smart_Career.csv')

# %%
Payton = [player for player in nba_players
                   if player['full_name'] == 'Elfrid Payton'][0]
Payton
# Out:
# {'id': 203901,
#  'full_name': 'Elfrid Payton',
#  'first_name': 'Elfrid',
#  'last_name': 'Payton',
#  'is_active': True}

# %%
Payton_career = playercareerstats.PlayerCareerStats(player_id= "203901")
Payton_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203901   2014-15        00  1610612753               ORL        21.0
# 1     203901   2015-16        00  1610612753               ORL        22.0
# 2     203901   2016-17        00  1610612753               ORL        23.0
# 3     203901   2017-18        00  1610612753               ORL        24.0
# 4     203901   2017-18        00  1610612756               PHX        24.0
# 5     203901   2017-18        00           0               TOT        24.0
# 6     203901   2018-19        00  1610612740               NOP        25.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  82  63  2489.0  301  ...    0.551   107   242  349  533  142   20  203
# 1  73  69  2145.0  318  ...    0.589    77   184  261  467   89   20  177
# 2  82  58  2412.0  430  ...    0.692    89   298  387  529   88   40  178
# ...

# %%
Payton_career = Payton_career.get_data_frames()[0]
Payton_career = Payton_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Payton_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    11    42    0.262
# 1        22.0    30    92    0.326
# 2        23.0    40   146    0.274
# 3        24.0    25    67    0.373
# 4        24.0     5    25    0.200
# 5        24.0    30    92    0.326
# 6        25.0    33   105    0.314

# %%
Payton_career = Payton_career.drop([3, 4])
Payton_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    11    42    0.262
# 1        22.0    30    92    0.326
# 2        23.0    40   146    0.274
# 5        24.0    30    92    0.326
# 6        25.0    33   105    0.314

# %%
Payton_career.to_csv('Elfrid_Payton_Career.csv')

# %%
Ennis = [player for player in nba_players
                   if player['full_name'] == 'Tyler Ennis'][0]
Ennis
# Out:
# {'id': 203898,
#  'full_name': 'Tyler Ennis',
#  'first_name': 'Tyler',
#  'last_name': 'Ennis',
#  'is_active': False}

# %%
Ennis_career = playercareerstats.PlayerCareerStats(player_id= "203898")
Ennis_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203898   2014-15        00  1610612756               PHX        20.0
# 1     203898   2014-15        00  1610612749               MIL        20.0
# 2     203898   2014-15        00           0               TOT        20.0
# 3     203898   2015-16        00  1610612749               MIL        21.0
# 4     203898   2016-17        00  1610612745               HOU        22.0
# 5     203898   2016-17        00  1610612747               LAL        22.0
# 6     203898   2016-17        00           0               TOT        22.0
# 7     203898   2017-18        00  1610612747               LAL        23.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0   8   0   58.0    9 ...    1.000     1     6    7   14    0    2    8   3
# 1  25   1  353.0   43 ...    0.600     6    22   28   59   18    3   34  33
# ...

# %%
Ennis_career = Ennis_career.get_data_frames()[0]
Ennis_career = Ennis_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Ennis_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     2     6    0.333
# 1        20.0    10    37    0.270
# 2        20.0    12    43    0.279
# 3        21.0    13    39    0.333
# 4        22.0     6    16    0.375
# 5        22.0    21    54    0.389
# 6        22.0    27    70    0.386
# 7        23.0    14    56    0.250

# %%
Ennis_career = Ennis_career.drop([0, 1, 4, 5])
Ennis_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 2        20.0    12    43    0.279
# 3        21.0    13    39    0.333
# 6        22.0    27    70    0.386
# 7        23.0    14    56    0.250

# %%
Ennis_career.to_csv('Tyler_Ennis_Career.csv')

# %%
Napier = [player for player in nba_players
                   if player['full_name'] == 'Shabazz Napier'][0]
Napier
# Out:
# {'id': 203894,
#  'full_name': 'Shabazz Napier',
#  'first_name': 'Shabazz',
#  'last_name': 'Napier',
#  'is_active': True}

# %%
Napier_career = playercareerstats.PlayerCareerStats(player_id= "203894")
Napier_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203894   2014-15        00  1610612748               MIA        23.0
# 1     203894   2015-16        00  1610612753               ORL        24.0
# 2     203894   2016-17        00  1610612757               POR        25.0
# 3     203894   2017-18        00  1610612757               POR        26.0
# 4     203894   2018-19        00  1610612751               BKN        27.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  51  10  1012.0   87 ...    0.786    17    96  113  130   40    4   81  76
# 1  55   0   600.0   68 ...    0.733     9    46   55   97   23    1   46  38
# 2  53   2   512.0   73 ...    0.776     8    53   61   67   32    2   41  38
# 3  74   9  1536.0  223 ...    0.841    26   144  170  150   81   14   90  84
# 4  56   2   983.0  169 ...    0.833    18    82  100  143   41   16   66  67
#
#    PTS
# 0  261
# 1  203
# 2  218
# 3  644
# 4  529
# ...

# %%
Napier_career = Napier_career.get_data_frames()[0]
Napier_career = Napier_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Napier_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    43   118    0.364
# 1        24.0    34   104    0.327
# 2        25.0    34    92    0.370
# 3        26.0    82   218    0.376
# 4        27.0    76   228    0.333

# %%
Napier_career.to_csv('Shabazz_Napier_Career.csv')

# %%
DLO = [player for player in nba_players
                   if player['full_name'] == "D'Angelo Russell"][0]
DLO
# Out:
# {'id': 1626156,
#  'full_name': "D'Angelo Russell",
#  'first_name': "D'Angelo",
#  'last_name': 'Russell',
#  'is_active': True}

# %%
DLO_career = playercareerstats.PlayerCareerStats(player_id= "1626156")
DLO_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626156   2015-16        00  1610612747               LAL        20.0
# 1    1626156   2016-17        00  1610612747               LAL        21.0
# 2    1626156   2017-18        00  1610612751               BKN        22.0
# 3    1626156   2018-19        00  1610612751               BKN        23.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  80  48  2259.0  392  ...    0.737    47   227  274  266   93   13  196
# 1  63  60  1811.0  351  ...    0.782    31   190  221  303   87   16  176
# 2  48  35  1234.0  278  ...    0.740    30   159  189  249   36   17  147
# 3  81  81  2448.0  659  ...    0.780    53   262  315  563  100   20  253
#
#     PF   PTS
# 0  142  1054
# 1  130   984
# 2   93   743
# 3  141  1712
#
# [4 rows x 27 columns]

# %%
DLO_career = DLO_career.get_data_frames()[0]
DLO_career = DLO_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
DLO_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   130   370    0.351
# 1        21.0   135   384    0.352
# 2        22.0    90   278    0.324
# 3        23.0   234   635    0.369

# %%
DLO_career.to_csv('DAngelo_Russell_Career.csv')

# %%
Mudiay = [player for player in nba_players
                   if player['full_name'] == "Emmanuel Mudiay"][0]
Mudiay
# Out:
# {'id': 1626144,
#  'full_name': 'Emmanuel Mudiay',
#  'first_name': 'Emmanuel',
#  'last_name': 'Mudiay',
#  'is_active': True}

# %%
Mudiay_career = playercareerstats.PlayerCareerStats(player_id= "1626144")
Mudiay_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626144   2015-16        00  1610612743               DEN        20.0
# 1    1626144   2016-17        00  1610612743               DEN        21.0
# 2    1626144   2017-18        00  1610612743               DEN        22.0
# 3    1626144   2017-18        00  1610612752               NYK        22.0
# 4    1626144   2017-18        00           0               TOT        22.0
# 5    1626144   2018-19        00  1610612752               NYK        23.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  68  66  2068.0  329 ...    0.670    32   200  232  372   65   35  217  141
# 1  55  41  1406.0  208 ...    0.784    29   149  178  217   41   13  123   95
# 2  42   0   752.0  129 ...    0.808    16    78   94  121   21    4   72   47
# 3  22  14   493.0   75 ...    0.686    10    48   58   85   20    7   41   33
# ...

# %%
Mudiay_career = Mudiay_career.get_data_frames()[0]
Mudiay_career = Mudiay_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Mudiay_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    74   232    0.319
# 1        21.0    56   178    0.315
# 2        22.0    38   102    0.373
# 3        22.0     9    46    0.196
# 4        22.0    47   148    0.318
# 5        23.0    69   210    0.329

# %%
Mudiay_career = Mudiay_career.drop([2, 3])
Mudiay_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    74   232    0.319
# 1        21.0    56   178    0.315
# 4        22.0    47   148    0.318
# 5        23.0    69   210    0.329

# %%
Mudiay_career.to_csv('Emmanuel_Mudiay_Career.csv')

# %%
Payne = [player for player in nba_players
                   if player['full_name'] == "Cameron Payne"][0]
Payne
# Out:
# {'id': 1626166,
#  'full_name': 'Cameron Payne',
#  'first_name': 'Cameron',
#  'last_name': 'Payne',
#  'is_active': True}

# %%
Payne_career = playercareerstats.PlayerCareerStats(player_id= "1626166")
Payne_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626166   2015-16        00  1610612760               OKC        21.0
# 1    1626166   2016-17        00  1610612760               OKC        22.0
# 2    1626166   2016-17        00  1610612741               CHI        22.0
# 3    1626166   2016-17        00           0               TOT        22.0
# 4    1626166   2017-18        00  1610612741               CHI        23.0
# 5    1626166   2018-19        00  1610612741               CHI        24.0
# 6    1626166   2018-19        00  1610612739               CLE        24.0
# 7    1626166   2018-19        00           0               TOT        24.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  57   1  698.0  114 ...    0.792     9    76   85  108   36    6   44  80
# 1  20   0  320.0   43 ...    1.000     2    29   31   40   10    4   16  38
# ...

# %%
Payne_career = Payne_career.get_data_frames()[0]
Payne_career = Payne_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Payne_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    36   111    0.324
# 1        22.0    16    52    0.308
# 2        22.0    11    34    0.324
# 3        22.0    27    86    0.314
# 4        23.0    35    91    0.385
# 5        24.0    16    59    0.271
# 6        24.0     9    25    0.360
# 7        24.0    25    84    0.298

# %%
Payne_career = Payne_career.drop([1, 2, 5, 6])
Payne_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0    36   111    0.324
# 3        22.0    27    86    0.314
# 4        23.0    35    91    0.385
# 7        24.0    25    84    0.298

# %%
Payne_career.to_csv('Cameron_Payne_Career.csv')

# %%
Rozier = [player for player in nba_players
                   if player['full_name'] == "Terry Rozier"][0]
Rozier
# Out:
# {'id': 1626179,
#  'full_name': 'Terry Rozier',
#  'first_name': 'Terry',
#  'last_name': 'Rozier',
#  'is_active': True}

# %%
Rozier_career = playercareerstats.PlayerCareerStats(player_id= "1626179")
Rozier_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626179   2015-16        00  1610612738               BOS        22.0
# 1    1626179   2016-17        00  1610612738               BOS        23.0
# 2    1626179   2017-18        00  1610612738               BOS        24.0
# 3    1626179   2018-19        00  1610612738               BOS        25.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  39   0   311.0   29 ...    0.800    24    39   63   37    6    1   19   23
# 1  74   0  1263.0  151 ...    0.773    40   187  227  131   45   11   47   69
# 2  80  16  2068.0  316 ...    0.772    63   313  376  232   80   19   80  123
# 3  79  14  1791.0  258 ...    0.785    32   275  307  231   68   21   68  101
#
#    PTS
# 0   72
# 1  410
# 2  900
# 3  708
#
# [4 rows x 27 columns]

# %%
Rozier_career = Rozier_career.get_data_frames()[0]
Rozier_career = Rozier_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Rozier_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0     6    27    0.222
# 1        23.0    57   179    0.318
# 2        24.0   153   402    0.381
# 3        25.0   119   337    0.353

# %%
Rozier_career.to_csv('Terry_Rozier_Career.csv')

# %%
Grant = [player for player in nba_players
                   if player['full_name'] == "Jerian Grant"][0]
Grant
# Out:
# {'id': 1626170,
#  'full_name': 'Jerian Grant',
#  'first_name': 'Jerian',
#  'last_name': 'Grant',
#  'is_active': True}

# %%
Grant_career = playercareerstats.PlayerCareerStats(player_id= "1626170")
Grant_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626170   2015-16        00  1610612752               NYK        23.0
# 1    1626170   2016-17        00  1610612741               CHI        24.0
# 2    1626170   2017-18        00  1610612741               CHI        25.0
# 3    1626170   2018-19        00  1610612753               ORL        26.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  76   6  1265.0  154 ...    0.780    23   120  143  177   50   10   87   97
# 1  63  28  1028.0  128 ...    0.890    17    94  111  121   47    8   44   93
# 2  74  26  1686.0  209 ...    0.745    31   140  171  342   63    8   89  132
# 3  60   1   939.0   92 ...    0.650    19    79   98  156   44    6   51   78
#
#    PTS
# 0  426
# 1  370
# 2  619
# 3  250
#
# [4 rows x 27 columns]

# %%
Grant_career = Grant_career.get_data_frames()[0]
Grant_career = Grant_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Grant_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    22   100    0.220
# 1        24.0    49   134    0.366
# 2        25.0    61   187    0.326
# 3        26.0    40   110    0.364

# %%
Grant_career.to_csv('Jerian_Grant_Career.csv')

# %%
Wright = [player for player in nba_players
                   if player['full_name'] == "Delon Wright"][0]
Wright
# Out:
# {'id': 1626153,
#  'full_name': 'Delon Wright',
#  'first_name': 'Delon',
#  'last_name': 'Wright',
#  'is_active': True}

# %%
Wright_career = playercareerstats.PlayerCareerStats(player_id= "1626153")
Wright_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626153   2015-16        00  1610612761               TOR        24.0
# 1    1626153   2016-17        00  1610612761               TOR        25.0
# 2    1626153   2017-18        00  1610612761               TOR        26.0
# 3    1626153   2018-19        00  1610612761               TOR        27.0
# 4    1626153   2018-19        00  1610612763               MEM        27.0
# 5    1626153   2018-19        00           0               TOT        27.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  27   1   229.0   36 ...    0.743     8    29   37   31    8    3   16    7
# 1  27   0   446.0   49 ...    0.764    16    32   48   57   27   11   25   31
# 2  69   4  1433.0  201 ...    0.829    45   153  198  200   72   33   78   81
# 3  49   2   897.0  127 ...    0.869    39    86  125  110   46   15   37   53
# ...

# %%
Wright_career = Wright_career.get_data_frames()[0]
Wright_career = Wright_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Wright_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        24.0     5    13    0.385
# 1        25.0    10    30    0.333
# 2        26.0    56   153    0.366
# 3        27.0    30    90    0.333
# 4        27.0    20    78    0.256
# 5        27.0    50   168    0.298

# %%
Wright_career = Wright_career.drop([3, 4])
Wright_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        24.0     5    13    0.385
# 1        25.0    10    30    0.333
# 2        26.0    56   153    0.366
# 5        27.0    50   168    0.298

# %%
Wright_career.to_csv('Delon_Wright_Career.csv')

# %%
Tyus = [player for player in nba_players
                   if player['full_name'] == "Tyus Jones"][0]
Tyus
# Out:
# {'id': 1626145,
#  'full_name': 'Tyus Jones',
#  'first_name': 'Tyus',
#  'last_name': 'Jones',
#  'is_active': True}

# %%
Tyus_career = playercareerstats.PlayerCareerStats(player_id= "1626145")
Tyus_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1626145   2015-16        00  1610612750               MIN        20.0
# 1    1626145   2016-17        00  1610612750               MIN        21.0
# 2    1626145   2017-18        00  1610612750               MIN        22.0
# 3    1626145   2018-19        00  1610612750               MIN        23.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  37   0   573.0   56 ...    0.718     7    40   47  108   31    3   33   33
# 1  60   0   774.0   75 ...    0.767    10    57   67  156   48    5   38   50
# 2  82  11  1467.0  150 ...    0.877    16   116  132  232   95    6   59  110
# 3  68  23  1560.0  185 ...    0.841    23   111  134  327   81    5   47   78
#
#    PTS
# 0  156
# 1  209
# 2  416
# 3  468
#
# [4 rows x 27 columns]

# %%
Tyus_career = Tyus_career.get_data_frames()[0]
Tyus_career = Tyus_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Tyus_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    16    53    0.302
# 1        21.0    26    73    0.356
# 2        22.0    45   129    0.349
# 3        23.0    40   126    0.317

# %%
Tyus_career.to_csv('Tyus_Jones_Career.csv')

# %%
Dunn = [player for player in nba_players
                   if player['full_name'] == "Kris Dunn"][0]
Dunn
# Out:
# {'id': 1627739,
#  'full_name': 'Kris Dunn',
#  'first_name': 'Kris',
#  'last_name': 'Dunn',
#  'is_active': True}

# %%
Dunn_career = playercareerstats.PlayerCareerStats(player_id= "1627739")
Dunn_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627739   2016-17        00  1610612750               MIN        23.0
# 1    1627739   2017-18        00  1610612741               CHI        24.0
# 2    1627739   2018-19        00  1610612741               CHI        25.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  78   7  1333.0  118 ...    0.610    24   142  166  188   78   36   89  178
# 1  52  43  1525.0  286 ...    0.737    24   197  221  310  104   27  150  174
# 2  46  44  1389.0  215 ...    0.797    19   168  187  277   68   21  104  166
#
#    PTS
# 0  293
# 1  699
# 2  519
#
# [3 rows x 27 columns]

# %%
Dunn_career = Dunn_career.get_data_frames()[0]
Dunn_career = Dunn_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Dunn_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0    21    73    0.288
# 1        24.0    43   134    0.321
# 2        25.0    34    96    0.354

# %%
Dunn_career.to_csv('Kris_Dunn_Career.csv')

# %%
Murray = [player for player in nba_players
                   if player['full_name'] == "Jamal Murray"][0]
Murray
# Out:
# {'id': 1627750,
#  'full_name': 'Jamal Murray',
#  'first_name': 'Jamal',
#  'last_name': 'Murray',
#  'is_active': True}

# %%
Murray_career = playercareerstats.PlayerCareerStats(player_id= "1627750")
Murray_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627750   2016-17        00  1610612743               DEN        20.0
# 1    1627750   2017-18        00  1610612743               DEN        21.0
# 2    1627750   2018-19        00  1610612743               DEN        22.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  82   9  1765.0  295  ...    0.883    41   173  214  170   51   24  113
# 1  81  80  2565.0  479  ...    0.905    82   215  297  274   79   28  172
# 2  75  74  2447.0  513  ...    0.848    65   252  317  363   67   27  158
#
#     PF   PTS
# 0  124   811
# 1  173  1352
# 2  153  1367
#
# [3 rows x 27 columns]

# %%
Murray_career = Murray_career.get_data_frames()[0]
Murray_career = Murray_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Murray_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   115   344    0.334
# 1        21.0   165   436    0.378
# 2        22.0   152   414    0.367

# %%
Murray_career.to_csv('Jamal_Murray_Career.csv')

# %%
Baldwin = [player for player in nba_players
                   if player['full_name'] == "Wade Baldwin IV"][0]
Baldwin
# Out:
# {'id': 1627735,
#  'full_name': 'Wade Baldwin IV',
#  'first_name': 'Wade',
#  'last_name': 'Baldwin IV',
#  'is_active': True}

# %%
Baldwin_career = playercareerstats.PlayerCareerStats(player_id= "1627735")
Baldwin_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627735   2016-17        00  1610612763               MEM        21.0
# 1    1627735   2017-18        00  1610612757               POR        22.0
# 2    1627735   2018-19        00  1610612757               POR        23.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  33   1  405.0   36 ...    0.838    11    35   46   61   18    7   39  40
# 1   7   0   80.0   14 ...    0.600     1     7    8    5    2    1    4  12
# 2  16   0   94.0   10 ...    0.727     2    13   15   12    1    2   14  11
#
#    PTS
# 0  106
# 1   38
# 2   30
#
# [3 rows x 27 columns]

# %%
Baldwin_career = Baldwin_career.get_data_frames()[0]
Baldwin_career = Baldwin_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Baldwin_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        21.0     3    22    0.136
# 1        22.0     4     5    0.800
# 2        23.0     2     9    0.222

# %%
Baldwin_career.to_csv('Wade_BaldwinIV_Career.csv')

# %%
Dejounte = [player for player in nba_players
                   if player['full_name'] == "Dejounte Murray"][0]
Dejounte
# Out:
# {'id': 1627749,
#  'full_name': 'Dejounte Murray',
#  'first_name': 'Dejounte',
#  'last_name': 'Murray',
#  'is_active': True}

# %%
Dejounte_career = playercareerstats.PlayerCareerStats(player_id= "1627749")
Dejounte_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1627749   2016-17        00  1610612759               SAS        20.0
# 1    1627749   2017-18        00  1610612759               SAS        21.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  38   8   322.0   50 ...    0.700     6    36   42   48    8    6   38   29
# 1  81  48  1743.0  270 ...    0.709   110   349  459  231   97   31  134  151
#
#    PTS
# 0  130
# 1  654
#
# [2 rows x 27 columns]

# %%
Dejounte_career = Dejounte_career.get_data_frames()[0]
Dejounte_career = Dejounte_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Dejounte_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     9    23    0.391
# 1        21.0     9    34    0.265

# %%
Dejounte_career.to_csv('Dejounte_Murray_Career.csv')

# %%
Fultz = [player for player in nba_players
                   if player['full_name'] == "Markelle Fultz"][0]
Fultz
# Out:
# {'id': 1628365,
#  'full_name': 'Markelle Fultz',
#  'first_name': 'Markelle',
#  'last_name': 'Fultz',
#  'is_active': True}

# %%
Fultz_career = playercareerstats.PlayerCareerStats(player_id= "1628365")
Fultz_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628365   2017-18        00  1610612755               PHI        20.0
# 1    1628365   2018-19        00  1610612755               PHI        20.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  14   0  253.0   45 ...    0.476    11    32   43   53   12    4   17  22
# 1  19  15  427.0   65 ...    0.568    26    44   70   59   17    5   25  52
#
#    PTS
# 0  100
# 1  155
#
# [2 rows x 27 columns]

# %%
Fultz_career = Fultz_career.get_data_frames()[0]
Fultz_career = Fultz_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Fultz_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0     0     1    0.000
# 1        20.0     4    14    0.286

# %%
Fultz_career.to_csv('Markelle_Fultz_Career.csv')

# %%
Lonzo = [player for player in nba_players
                   if player['full_name'] == "Lonzo Ball"][0]
Lonzo
# Out:
# {'id': 1628366,
#  'full_name': 'Lonzo Ball',
#  'first_name': 'Lonzo',
#  'last_name': 'Ball',
#  'is_active': True}

# %%
Lonzo_career = playercareerstats.PlayerCareerStats(player_id= "1628366")
Lonzo_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628366   2017-18        00  1610612747               LAL        20.0
# 1    1628366   2018-19        00  1610612747               LAL        21.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  52  50  1780.0  203 ...    0.451    69   291  360  376   88   43  136  117
# 1  47  45  1423.0  185 ...    0.417    54   197  251  255   69   19  103  114
#
#    PTS
# 0  528
# 1  465
#
# [2 rows x 27 columns]

# %%
Lonzo_career = Lonzo_career.get_data_frames()[0]
Lonzo_career = Lonzo_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Lonzo_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    90   295    0.305
# 1        21.0    75   228    0.329

# %%
Lonzo_career.to_csv('Lonzo_Ball_Career.csv')

# %%
Fox = [player for player in nba_players
                   if player['full_name'] == "De'Aaron Fox"][0]
Fox
# Out:
# {'id': 1628368,
#  'full_name': "De'Aaron Fox",
#  'first_name': "De'Aaron",
#  'last_name': 'Fox',
#  'is_active': True}

# %%
Fox_career = playercareerstats.PlayerCareerStats(player_id= "1628368")
Fox_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628368   2017-18        00  1610612758               SAC        20.0
# 1    1628368   2018-19        00  1610612758               SAC        21.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  73  61  2026.0  328  ...    0.723    33   171  204  320   70   20  173
# 1  81  81  2546.0  505  ...    0.727    43   261  304  590  133   45  227
#
#     PF   PTS
# 0  163   844
# 1  204  1399
#
# [2 rows x 27 columns]

# %%
Fox_career = Fox_career.get_data_frames()[0]
Fox_career = Fox_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Fox_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    47   153    0.307
# 1        21.0    86   232    0.371

# %%
Fox_career.to_csv('DeAaron_Fox_Career.csv')

# %%
Frank = [player for player in nba_players
                   if player['full_name'] == "Frank Ntilikina"][0]
Frank
# Out:
# {'id': 1628373,
#  'full_name': 'Frank Ntilikina',
#  'first_name': 'Frank',
#  'last_name': 'Ntilikina',
#  'is_active': True}

# %%
Frank_career = playercareerstats.PlayerCareerStats(player_id= "1628373")
Frank_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628373   2017-18        00  1610612752               NYK        19.0
# 1    1628373   2018-19        00  1610612752               NYK        20.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  78   9  1706.0  182 ...    0.721    37   140  177  250   65   18  131  181
# 1  43  16   904.0   95 ...    0.767    12    75   87  121   30   14   56  104
#
#    PTS
# 0  463
# 1  246
#
# [2 rows x 27 columns]

# %%
Frank_career = Frank_career.get_data_frames()[0]
Frank_career = Frank_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Frank_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        19.0    50   157    0.318
# 1        20.0    33   115    0.287

# %%
Frank_career.to_csv('Frank_Ntilikina_Career.csv')

# %%
DSJ = [player for player in nba_players
                   if player['full_name'] == "Dennis Smith Jr."][0]
DSJ
# Out:
# {'id': 1628372,
#  'full_name': 'Dennis Smith Jr.',
#  'first_name': 'Dennis',
#  'last_name': 'Smith Jr.',
#  'is_active': True}

# %%
DSJ_career = playercareerstats.PlayerCareerStats(player_id= "1628372")
DSJ_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628372   2017-18        00  1610612742               DAL        20.0
# 1    1628372   2018-19        00  1610612742               DAL        21.0
# 2    1628372   2018-19        00  1610612752               NYK        21.0
# 3    1628372   2018-19        00           0               TOT        21.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  69  69  2049.0  404  ...    0.694    50   210  260  358   71   18  194
# 1  32  32   908.0  157  ...    0.695    18    79   97  138   40   11  100
# 2  21  18   600.0  121  ...    0.568    14    44   58  114   27    9   54
# 3  53  50  1508.0  278  ...    0.635    32   123  155  252   67   20  154
#
#     PF   PTS
# 0  152  1048
# 1   82   414
# 2   47   308
# 3  129   722
#
# [4 rows x 27 columns]

# %%
DSJ_career = DSJ_career.get_data_frames()[0]
DSJ_career = DSJ_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
DSJ_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   106   339    0.313
# 1        21.0    43   125    0.344
# 2        21.0    24    83    0.289
# 3        21.0    67   208    0.322

# %%
DSJ_career = DSJ_career.drop([1,2])
DSJ_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   106   339    0.313
# 3        21.0    67   208    0.322

# %%
DSJ_career.to_csv('Dennis_Smith_Jr_Career.csv')

# %%
White = [player for player in nba_players
                   if player['full_name'] == "Derrick White"][0]
White
# Out:
# {'id': 1628401,
#  'full_name': 'Derrick White',
#  'first_name': 'Derrick',
#  'last_name': 'White',
#  'is_active': True}

# %%
White_career = playercareerstats.PlayerCareerStats(player_id= "1628401")
White_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628401   2017-18        00  1610612759               SAS        23.0
# 1    1628401   2018-19        00  1610612759               SAS        24.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  17   0   139.0   16 ...    0.700     5    21   26    9    4    3    6    8
# 1  67  55  1728.0  260 ...    0.772    35   212  247  263   67   47   97  145
#
#    PTS
# 0   54
# 1  663
#
# [2 rows x 27 columns]

# %%
White_career = White_career.get_data_frames()[0]
White_career = White_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
White_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        23.0     8    13    0.615
# 1        24.0    48   142    0.338

# %%
White_career.to_csv('Derrick_White_Career.csv')

# %%
Doncic = [player for player in nba_players
                   if player['full_name'] == "Luka Doncic"][0]
Doncic
# Out:
# {'id': 1629029,
#  'full_name': 'Luka Doncic',
#  'first_name': 'Luka',
#  'last_name': 'Doncic',
#  'is_active': True}

# %%
Doncic_career = playercareerstats.PlayerCareerStats(player_id= "1629029")
Doncic_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629029   2018-19        00  1610612742               DAL        20.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  72  72  2318.0  506  ...    0.713    86   477  563  429   77   25  247
#
#     PF   PTS
# 0  137  1526
#
# [1 rows x 27 columns]

# %%
Doncic_career = Doncic_career.get_data_frames()[0]
Doncic_career = Doncic_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Doncic_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   168   514    0.327

# %%
Doncic_career.to_csv('Luka_Doncic_Career.csv')

# %%
Young = [player for player in nba_players
                   if player['full_name'] == "Trae Young"][0]
Young
# Out:
# {'id': 1629027,
#  'full_name': 'Trae Young',
#  'first_name': 'Trae',
#  'last_name': 'Young',
#  'is_active': True}

# %%
Young_career = playercareerstats.PlayerCareerStats(player_id= "1629027")
Young_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629027   2018-19        00  1610612737               ATL        20.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  81  81  2503.0  525  ...    0.829    64   237  301  653   72   15  308
#
#     PF   PTS
# 0  140  1549
#
# [1 rows x 27 columns]

# %%
Young_career = Young_career.get_data_frames()[0]
Young_career = Young_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Young_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   156   482    0.324

# %%
Young_career.to_csv('Trae_Young_Career.csv')

# %%
Sexton = [player for player in nba_players
                   if player['full_name'] == "Collin Sexton"][0]
Sexton
# Out:
# {'id': 1629012,
#  'full_name': 'Collin Sexton',
#  'first_name': 'Collin',
#  'last_name': 'Sexton',
#  'is_active': True}

# %%
Sexton_career = playercareerstats.PlayerCareerStats(player_id= "1629012")
Sexton_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629012   2018-19        00  1610612739               CLE        20.0
#
#    GP  GS     MIN  FGM  ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0  82  72  2605.0  519  ...    0.839    57   179  236  243   44    6  185
#
#     PF   PTS
# 0  186  1371
#
# [1 rows x 27 columns]

# %%
Sexton_career = Sexton_career.get_data_frames()[0]
Sexton_career = Sexton_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Sexton_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0   119   296    0.402

# %%
Sexton_career.to_csv('Collin_Sexton_Career.csv')

# %%
SGA = [player for player in nba_players
                   if player['full_name'] == "Shai Gilgeous-Alexander"][0]
SGA
# Out:
# {'id': 1628983,
#  'full_name': 'Shai Gilgeous-Alexander',
#  'first_name': 'Shai',
#  'last_name': 'Gilgeous-Alexander',
#  'is_active': True}

# %%
SGA_career = playercareerstats.PlayerCareerStats(player_id= "1628983")
SGA_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  82  73  2174.0  341 ...      0.8    57   175  232  270   96   45  141  175
#
#    PTS
# 0  889
#
# [1 rows x 27 columns]

# %%
SGA_career = SGA_career.get_data_frames()[0]
SGA_career = SGA_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
SGA_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        20.0    51   139    0.367

# %%
SGA_career.to_csv('Shai_Gilgeous-Alexander_Career.csv')

# %%
AHoliday = [player for player in nba_players
                   if player['full_name'] == "Aaron Holiday"][0]
AHoliday
# Out:
# {'id': 1628988,
#  'full_name': 'Aaron Holiday',
#  'first_name': 'Aaron',
#  'last_name': 'Holiday',
#  'is_active': True}

# %%
AHoliday_career = playercareerstats.PlayerCareerStats(player_id= "1628988")
AHoliday_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628988   2018-19        00  1610612754               IND        22.0
#
#    GP  GS    MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0  50   0  646.0  105 ...     0.82     5    62   67   87   21   13   40  71
#
#    PTS
# 0  294
#
# [1 rows x 27 columns]

# %%
AHoliday_career = AHoliday_career.get_data_frames()[0]
AHoliday_career = AHoliday_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
AHoliday_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    43   127    0.339

# %%
AHoliday_career.to_csv('Aaron_Holiday_Career.csv')

# %%
Shamet = [player for player in nba_players
                   if player['full_name'] == "Landry Shamet"][0]
Shamet
# Out:
# {'id': 1629013,
#  'full_name': 'Landry Shamet',
#  'first_name': 'Landry',
#  'last_name': 'Shamet',
#  'is_active': True}

# %%
Shamet_career = playercareerstats.PlayerCareerStats(player_id= "1629013")
Shamet_career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1629013   2018-19        00  1610612755               PHI        22.0
# 1    1629013   2018-19        00  1610612746               LAC        22.0
# 2    1629013   2018-19        00           0               TOT        22.0
#
#    GP  GS     MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  54   4  1108.0  153 ...    0.815    14    64   78   59   24    8   26  106
# 1  25  23   694.0   87 ...    0.795     7    49   56   58   13    2   19   49
# 2  79  27  1802.0  240 ...    0.806    21   113  134  117   37   10   45  155
#
#    PTS
# 0  449
# 1  273
# 2  722
#
# [3 rows x 27 columns]

# %%
Shamet_career = Shamet_career.get_data_frames()[0]
Shamet_career = Shamet_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Shamet_career.head(12)
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    99   245    0.404
# 1        22.0    68   151    0.450
# 2        22.0   167   396    0.422

# %%
Shamet_career = Shamet_career.drop([0, 1])
Shamet_career
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 2        22.0   167   396    0.422

# %%
Shamet_career.to_csv('Landry_Shamet_Career.csv')

# %%
CP3 = [player for player in nba_players
                   if player['full_name'] == "Chris Paul"][0]
CP3
# Out:
# {'id': 101108,
#  'full_name': 'Chris Paul',
#  'first_name': 'Chris',
#  'last_name': 'Paul',
#  'is_active': True}

# %%
CP3_career = playercareerstats.PlayerCareerStats(player_id= "101108")
CP3_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      101108   2005-06        00  1610612740               NOK        21.0
# 1      101108   2006-07        00  1610612740               NOK        22.0
# 2      101108   2007-08        00  1610612740               NOH        23.0
# 3      101108   2008-09        00  1610612740               NOH        24.0
# 4      101108   2009-10        00  1610612740               NOH        25.0
# 5      101108   2010-11        00  1610612740               NOH        26.0
# 6      101108   2011-12        00  1610612746               LAC        27.0
# 7      101108   2012-13        00  1610612746               LAC        28.0
# 8      101108   2013-14        00  1610612746               LAC        29.0
# 9      101108   2014-15        00  1610612746               LAC        30.0
# 10     101108   2015-16        00  1610612746               LAC        31.0
# ...

# %%
CP3_career = CP3_career.get_data_frames()[0]
CP3_career = CP3_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
CP3_career.head(15)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         21.0    50   177    0.282
# 1         22.0    50   143    0.350
# 2         23.0    92   249    0.369
# 3         24.0    64   176    0.364
# 4         25.0    52   127    0.409
# 5         26.0    71   183    0.388
# 6         27.0    79   213    0.371
# 7         28.0    76   232    0.328
# 8         29.0    78   212    0.368
# 9         30.0   139   349    0.398
# 10        31.0   122   329    0.371
# 11        32.0   124   302    0.411
# 12        33.0   144   379    0.380
# 13        34.0   127   355    0.358

# %%
Parker = [player for player in nba_players
                   if player['full_name'] == "Tony Parker"][0]
Parker
# Out:
# {'id': 2225,
#  'full_name': 'Tony Parker',
#  'first_name': 'Tony',
#  'last_name': 'Parker',
#  'is_active': True}

# %%
Parker_career = playercareerstats.PlayerCareerStats(player_id= "2225")
Parker_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2225   2001-02        00  1610612759               SAS        20.0
# 1        2225   2002-03        00  1610612759               SAS        21.0
# 2        2225   2003-04        00  1610612759               SAS        22.0
# 3        2225   2004-05        00  1610612759               SAS        23.0
# 4        2225   2005-06        00  1610612759               SAS        24.0
# 5        2225   2006-07        00  1610612759               SAS        25.0
# 6        2225   2007-08        00  1610612759               SAS        26.0
# 7        2225   2008-09        00  1610612759               SAS        27.0
# 8        2225   2009-10        00  1610612759               SAS        28.0
# 9        2225   2010-11        00  1610612759               SAS        29.0
# 10       2225   2011-12        00  1610612759               SAS        30.0
# ...

# %%
Parker_career = Parker_career.get_data_frames()[0]
Parker_career = Parker_career.loc[:, ["PLAYER_AGE", "FG3M", "FG3A", "FG3_PCT"]]
Parker_career.head(20)
# Out:
#     PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0         20.0    61   189    0.323
# 1         21.0    82   243    0.337
# 2         22.0    62   199    0.312
# 3         23.0    43   156    0.276
# 4         24.0    11    36    0.306
# 5         25.0    15    38    0.395
# 6         26.0    17    66    0.258
# 7         27.0    19    65    0.292
# 8         28.0    10    34    0.294
# 9         29.0    25    70    0.357
# 10        30.0    14    61    0.230
# 11        31.0    24    68    0.353
# 12        32.0    25    67    0.373
# 13        33.0    38    89    0.427
# 14        34.0    27    65    0.415
# 15        35.0    23    69    0.333
# 16        36.0    10    37    0.270
# 17        36.0    13    51    0.255
