# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv(os.path.join("Darren_Collison_Career.csv"))
df = df.drop("Unnamed: 0", axis=1)
df
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    46   115    0.400
# 1        23.0    41   124    0.331
# 2        24.0    34    94    0.362
# 3        25.0    48   136    0.353
# 4        26.0    71   189    0.376
# 5        27.0    60   161    0.373
# 6        28.0    87   217    0.401
# 7        29.0    73   175    0.417
# 8        30.0    96   205    0.468
# 9        31.0    79   194    0.407

# %%
hold = df["FG3_PCT"].mean()
track = 0
inc=1
a=[]
for k in df["FG3_PCT"]:
    if hold < k:
        temp = 1
    elif hold>k:
        temp = 0
    a.append(temp)
    inc+=1
df= pd.DataFrame(df)
df['Outcome']=a

df
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT  Outcome
# 0        22.0    46   115    0.400        1
# 1        23.0    41   124    0.331        0
# 2        24.0    34    94    0.362        0
# 3        25.0    48   136    0.353        0
# 4        26.0    71   189    0.376        0
# 5        27.0    60   161    0.373        0
# 6        28.0    87   217    0.401        1
# 7        29.0    73   175    0.417        1
# 8        30.0    96   205    0.468        1
# 9        31.0    79   194    0.407        1

# %%
print(hold)
# Out:
# 0.3888

# %%
target = df["Outcome"]
target_names = ["negative", "positive"]

# %%
data = df.drop("Outcome", axis=1)
feature_names = data.columns
data
# Out:
#    PLAYER_AGE  FG3M  FG3A  FG3_PCT
# 0        22.0    46   115    0.400
# 1        23.0    41   124    0.331
# 2        24.0    34    94    0.362
# 3        25.0    48   136    0.353
# 4        26.0    71   189    0.376
# 5        27.0    60   161    0.373
# 6        28.0    87   217    0.401
# 7        29.0    73   175    0.417
# 8        30.0    96   205    0.468
# 9        31.0    79   194    0.407

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
years = df.count()
train_scores = []
test_scores = []
for k in range(1, 9, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
fig = plt.figure()
plt.plot(range(1, 9, 2), train_scores, marker='o')
plt.plot(range(1, 9, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()

fig.savefig('Darren.png',)
# Out:
# k: 1, Train/Test Score: 1.000/0.333
# k: 3, Train/Test Score: 0.714/1.000
# k: 5, Train/Test Score: 0.714/0.667
# k: 7, Train/Test Score: 0.571/0.333

# %%
#
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
print('k=5 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=5 Test Acc: 0.667
